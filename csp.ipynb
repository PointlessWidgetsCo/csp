# %%
import pandas as pd

# %%
uni_df = pd.read_excel('./csp.xlsm', sheet_name='Uni', usecols='A:D', dtype='str')

# %%
course_df = pd.read_excel('./csp.xlsm', sheet_name='Course', dtype='str')
course_df['Updated'] = course_df['Updated'].str.split(' ').str[0]

course_df = course_df.drop('FoE Name', axis=1) # drop the FoE name which we will reconstruct later

# %%
foe_dict = {}
foe_dict['asced2'] = pd.read_excel('./csp.xlsm', sheet_name='FoE', usecols='A:B', dtype='str').dropna()
foe_dict['asced4'] = pd.read_excel('./csp.xlsm', sheet_name='FoE', usecols='D:E', dtype='str').dropna()
foe_dict['asced6'] = pd.read_excel('./csp.xlsm', sheet_name='FoE', usecols='G:H', dtype='str').dropna()

# %%
def title_except_and(text):
    words = text.split()
    return ' '.join([w.capitalize() if w.lower() != 'and' else 'and' for w in words])

foe_dict['asced2']['Name'] = foe_dict['asced2']['Name'].apply(title_except_and)

# %%
foe_dict['asced6']['ASCED 4'] = foe_dict['asced6']['ASCED 6'].str[:4]
foe_dict['asced6']['ASCED 2'] = foe_dict['asced6']['ASCED 6'].str[:2]


foe_df = (foe_dict['asced6']
          .merge(foe_dict['asced4'], how='left', on='ASCED 4')
          .merge(foe_dict['asced2'], how='left', on='ASCED 2')
)

foe_df = (foe_df
          .rename(columns={'ASCED 6':'asced', 'Name.2':'FoE_asced6', 'Name.1':'FoE_asced4', 'Name':'FoE_asced2'})
          .reindex(columns=['asced','FoE_asced6', 'FoE_asced4', 'FoE_asced2'])
)

# %%
output_df = (
    course_df
    .merge(foe_df, how='left', left_on='FoE', right_on='asced')
    .merge(uni_df, how='left', left_on='Uni ID', right_on='ID')
    .reindex(columns=['Course', 'Description', 'Duration', 'Location', 'URL_x', 'Updated', 'FoE', 'FoE_asced6', 'FoE_asced4', 'FoE_asced2', 'State', 'Name'])
    .rename(columns={'Name':'Uni', 'URL_x':'URL'})
)

output_df = output_df.fillna('')

# %%
output_df
# Out:
#                                                  Course  \
# 0                          Master of Teaching (Primary)
# 1                        Master of Teaching (Secondary)
# 2     Graduate Certificate in Agricultural Business ...
# 3                   Graduate Certificate in Agriculture
# 4      Graduate Certificate in Environmental Management
# ...                                                 ...
# 1897  Master of Teaching (Secondary)/Graduate Certif...
# 1898                Graduate Certificate in Supervision
# 1899            Graduate Diploma in Spiritual Direction
# 1900                    Graduate Diploma in Supervision
# 1901                      Master of Spiritual Direction
#
#                                             Description  \
# 0     The Master of Teaching (Primary) (MTch (Prim))...
# 1     The Master of Teaching (Secondary) (MTch (Sec)...
# 2     Gain a solid foundation for your agribusiness ...
# 3     The Graduate Certificate in Agriculture from C...
# 4     Do you want to be a changemaker for a sustaina...
# ...                                                 ...
# 1897  This is a graduate entry, preservice teacher e...
# 1898  Supervision is the discipline of enabling prof...
# 1899  Spiritual Direction is the process and practic...
# 1900                                                  –
# 1901  The Master of Spiritual Direction is a coursew...
#
#                                        Duration  \
# 0                            Full time: 2 years
# 1                            Full time: 2 years
# 2                    Minimum time - 0.5 year(s)
# 3                    Minimum time - 0.5 year(s)
# 4                    Minimum time - 0.5 year(s)
# ...                                         ...
# 1897  2 years full-time or equivalent part-time
# 1898                           1 year part-time
# 1899                          2 years part-time
# 1900                                          –
# 1901                          3 years part-time
#
#                                       Location  \
# 0                               Lake Macquarie
# 1                               Lake Macquarie
# 2                                       Online
# 3                                       Online
# 4                                       Online
# ...                                        ...
# 1897  Brisbane, Melbourne, Online, Strathfield
# 1898                                    Online
# 1899                                    Online
# 1900                                    Online
# 1901                                    Online
#
#                                                     URL     Updated     FoE  \
# 0     https://www.avondale.edu.au/course/master-of-t...  2025-03-27  070103
# 1     https://www.avondale.edu.au/course/master-of-t...  2025-03-27  070105
# 2     https://study.csu.edu.au/courses/graduate-cert...  2025-03-27  080321
# 3     https://study.csu.edu.au/courses/graduate-cert...  2025-03-27  050101
# 4     https://study.csu.edu.au/courses/graduate-cert...  2025-03-27  050901
# ...                                                 ...         ...     ...
# 1897  https://www.acu.edu.au/course/master-of-teachi...  2025-03-31  070105
# 1898  https://www.acu.edu.au/course/graduate-certifi...  2025-03-31  070105
# 1899  https://www.acu.edu.au/course/graduate-diploma...  2025-03-31  091703
# 1900  https://www.acu.edu.au/course/graduate-diploma...  2025-03-31  080399
# 1901  https://www.acu.edu.au/course/master-of-spirit...  2025-03-31  091703
#
#                                FoE_asced6                        FoE_asced4  \
# 0              Teacher Education: Primary                 Teacher Education
# 1            Teacher Education: Secondary                 Teacher Education
# 2        Farm Management and Agribusiness           Business and Management
# 3                    Agricultural Science                       Agriculture
# 4     Land, Parks and Wildlife Management             Environmental Studies
# ...                                   ...                               ...
# 1897         Teacher Education: Secondary                 Teacher Education
# 1898         Teacher Education: Secondary                 Teacher Education
# 1899                    Religious Studies  Philosophy and Religious Studies
# 1900      Business and Management, n.e.c.           Business and Management
# 1901                    Religious Studies  Philosophy and Religious Studies
#
#                                           FoE_asced2     State  \
# 0                                          Education       NSW
# 1                                          Education       NSW
# 2                            Management and Commerce       NSW
# 3     Agriculture, Environmental and Related Studies       NSW
# 4     Agriculture, Environmental and Related Studies       NSW
# ...                                              ...       ...
# 1897                                       Education  National
# 1898                                       Education  National
# 1899                             Society and Culture  National
# 1900                         Management and Commerce  National
# 1901                             Society and Culture  National
#
#                                  Uni
# 0                Avondale University
# 1                Avondale University
# 2           Charles Sturt University
# 3           Charles Sturt University
# 4           Charles Sturt University
# ...                              ...
# 1897  Australian Catholic University
# 1898  Australian Catholic University
# 1899  Australian Catholic University
# 1900  Australian Catholic University
# 1901  Australian Catholic University
#
# [1902 rows x 12 columns]

# %%
# Convert the DataFrame to the required JSON format
json_output = {
    "data": output_df.to_dict(orient="records")  # Convert each row to a dictionary
}

# Print or save the JSON output
import json
with open("csp.json", "w") as f:
    json.dump(json_output, f, indent=4)
